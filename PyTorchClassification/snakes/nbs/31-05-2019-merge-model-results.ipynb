# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('submission-3.csv')
df2 = pd.read_csv('test_result.csv')

# %%
df1.head()
# Out:
#                                filename  agkistrodon_contortrix  \
# 0  165fbd2c4d50e3b3828a0a577b79e3ad.jpg               -6.059806
# 1  1803e217e6aa4d056427d74b8fb8d67f.jpg               -5.791821
# 2  3af642cc5cb8da8ac3575be307b51e00.jpg               -6.211742
# 3  ffc09bb5badcd5754d8b2b12cc249483.jpg               -6.673999
# 4  b05af1475bc8371b74436779102be816.jpg               -5.821882
#
#    agkistrodon_piscivorus  boa_imperator  carphophis_amoenus  charina_bottae  \
# 0               -5.934019      -5.770509           -6.226341       -6.209627
# 1               -6.457109      -5.765462           -6.006543       -6.533270
# 2               -5.691241      -5.882664           -6.101466       -5.759951
# 3               -5.489079      -6.005888           -5.639378       -5.677656
# 4               -5.746684      -6.023958           -6.066875       -5.667871
#
#    coluber_constrictor  crotalus_adamanteus  crotalus_atrox  \
# ...

# %%
df2.head()
# Out:
#                                filename  agkistrodon_contortrix  \
# 0  165fbd2c4d50e3b3828a0a577b79e3ad.jpg               -6.181486
# 1  1803e217e6aa4d056427d74b8fb8d67f.jpg               -5.588114
# 2  3af642cc5cb8da8ac3575be307b51e00.jpg               -5.633822
# 3  ffc09bb5badcd5754d8b2b12cc249483.jpg               -5.688223
# 4  b05af1475bc8371b74436779102be816.jpg               -6.636148
#
#    agkistrodon_piscivorus  boa_imperator  carphophis_amoenus  charina_bottae  \
# 0               -6.250752      -5.961596           -6.810628       -6.048976
# 1               -5.500091      -5.761290           -6.151634       -6.246809
# 2               -5.770417      -5.660830           -7.878528       -6.341867
# 3               -4.945308      -5.644756           -5.709976       -5.772057
# 4               -5.701120      -5.948798           -6.391585       -5.710640
#
#    coluber_constrictor  crotalus_adamanteus  crotalus_atrox  \
# ...

# %%
df1 = df1.set_index('filename')
df2 = df2.set_index('filename')

# %%
df = (df1 + df2) / 2
df = df.reset_index()

# %%
df.head()
# Out:
#                                filename  agkistrodon_contortrix  \
# 0  00046ff8b04d6fe7f9c5a9d8dca33561.jpg               -6.150836
# 1  0004913b37b5293e5a33eb593f8b5aea.jpg               -5.768862
# 2  000a06bf72e2d6757b6aabc64b3d6413.jpg                2.345511
# 3  000a282c4aa89ddee660214d272df598.jpg               -5.911226
# 4  000a6431024d41527975019019ef58d6.jpg               -5.611860
#
#    agkistrodon_piscivorus  boa_imperator  carphophis_amoenus  charina_bottae  \
# 0               -6.011949      -5.840306           -5.873388       -6.290583
# 1               -5.788089      -5.877038           -5.950462       -5.875797
# 2               -6.001979      -6.023907           -6.174453       -6.033206
# 3               -6.166631      -5.865539           -5.704944       -5.996959
# 4               -5.504548      -5.776730           -5.722828       -6.249200
#
#    coluber_constrictor  crotalus_adamanteus  crotalus_atrox  \
# ...

# %%
df[df.filename == '165fbd2c4d50e3b3828a0a577b79e3ad.jpg']
# Out:
#                                   filename  agkistrodon_contortrix  \
# 1568  165fbd2c4d50e3b3828a0a577b79e3ad.jpg               -6.120646
#
#       agkistrodon_piscivorus  boa_imperator  carphophis_amoenus  \
# 1568               -6.092386      -5.866052           -6.518485
#
#       charina_bottae  coluber_constrictor  crotalus_adamanteus  \
# 1568       -6.129301            -6.540064            -6.275626
#
#       crotalus_atrox  crotalus_horridus         ...           \
# 1568       -5.828962          -6.083183         ...
#
#       regina_septemvittata  rhinocheilus_lecontei  storeria_dekayi  \
# 1568             -6.231535              -6.207445        -5.867772
#
#       storeria_occipitomaculata  thamnophis_elegans  thamnophis_marcianus  \
# 1568                  -6.330234           -6.098647             -5.776992
#
#       thamnophis_ordinoides  thamnophis_proximus  thamnophis_radix  \
# 1568              -5.682113            -5.905668         -5.944632
#
# ...

# %%
df.to_csv('submission-4.csv', index=False)

# %%
df.loc[np.abs(df['agkistrodon_contortrix'] - 0.01111111) < 0.0001, 'thamnophis_sirtalis'] = 0.012

# %%
df[np.abs(df['agkistrodon_contortrix'] - 0.01111111) < 0.0001]
# Out:
#                                    filename  agkistrodon_contortrix  \
# 221    035b83d6eb12ca399d5fb7a5a4f5b73b.jpg                0.011111
# 448    06a3288602939c7f03827215e80e1a1e.jpg                0.011111
# 664    094684c7f05726dcf48edd40f521de12.jpg                0.011111
# 1262   122231ec40704f3077b5e08d9545e682.jpg                0.011111
# 1405   142f43fd0a314ecd7f3e4cbfc1f3080c.jpg                0.011111
# 1417   145e1fed44c0608b2510495e1da186e6.jpg                0.011111
# 1536   1609b108e31ccb318ee8e475ca72074e.jpg                0.011111
# 1976   1c56622f067257a814254b3a0d66a504.jpg                0.011111
# 2506   23f3c8f701c8fa48f1fce47039a84bb3.jpg                0.011111
# 3031   2b8060650fbc5c4d04c831e37b6a2af3.jpg                0.011111
# 3053   2bcb7604d1e6611d3911efb09d0760a6.jpg                0.011111
# 3222   2e23ade63c4e32b728a423ff19e52ef1.jpg                0.011111
# 4365   3f014dd954ba56697215fcae131f7eac.jpg                0.011111
# ...

# %%
np.ones((44, 45), dtype=np.float)/90
# Out:
# array([[0.01111111, 0.01111111, 0.01111111, ..., 0.01111111, 0.01111111,
#         0.01111111],
#        [0.01111111, 0.01111111, 0.01111111, ..., 0.01111111, 0.01111111,
#         0.01111111],
#        [0.01111111, 0.01111111, 0.01111111, ..., 0.01111111, 0.01111111,
#         0.01111111],
#        ...,
#        [0.01111111, 0.01111111, 0.01111111, ..., 0.01111111, 0.01111111,
#         0.01111111],
#        [0.01111111, 0.01111111, 0.01111111, ..., 0.01111111, 0.01111111,
#         0.01111111],
#        [0.01111111, 0.01111111, 0.01111111, ..., 0.01111111, 0.01111111,
#         0.01111111]])
